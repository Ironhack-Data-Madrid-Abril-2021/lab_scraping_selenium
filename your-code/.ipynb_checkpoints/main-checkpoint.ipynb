# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from selenium) (1.25.11)

# %%
from selenium import webdriver

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise

PATH = ChromeDriverManager().install()
webdriver.Chrome(PATH).get('https://www.google.es')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Get LATEST driver version for 90.0.4430
# Trying to download new driver from https://chromedriver.storage.googleapis.com/90.0.4430.24/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/usuario/.wdm/drivers/chromedriver/mac64/90.0.4430.24]

# %%
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (3.4.1)
# Requirement already satisfied: crayons in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from webdriver-manager) (0.4.0)
# Requirement already satisfied: requests in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from webdriver-manager) (2.24.0)
# Requirement already satisfied: configparser in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from webdriver-manager) (5.0.2)
# Requirement already satisfied: colorama in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from crayons->webdriver-manager) (0.4.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from requests->webdriver-manager) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from requests->webdriver-manager) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from requests->webdriver-manager) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from requests->webdriver-manager) (2.10)

# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (2.5.0)
# Requirement already satisfied: pyOpenSSL>=16.2.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (19.1.0)
# Requirement already satisfied: service-identity>=16.0.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (21.1.0)
# Requirement already satisfied: cryptography>=2.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (3.1.1)
# Requirement already satisfied: PyDispatcher>=2.0.5; platform_python_implementation == "CPython" in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: Twisted[http2]>=17.9.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (21.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (1.0.4)
# Requirement already satisfied: h2<4.0,>=3.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (3.2.0)
# Requirement already satisfied: cssselect>=0.9.1 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: protego>=0.1.15 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (0.1.16)
# Requirement already satisfied: queuelib>=1.4.2 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (1.6.1)
# Requirement already satisfied: lxml>=3.5.0; platform_python_implementation == "CPython" in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (4.6.1)
# Requirement already satisfied: itemadapter>=0.1.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (0.2.0)
# Requirement already satisfied: w3lib>=1.17.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (1.22.0)
# Requirement already satisfied: zope.interface>=4.1.3 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (5.1.2)
# Requirement already satisfied: parsel>=1.5.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from scrapy) (1.6.0)
# Requirement already satisfied: six>=1.5.2 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from pyOpenSSL>=16.2.0->scrapy) (1.15.0)
# Requirement already satisfied: pyasn1-modules in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from service-identity>=16.0.0->scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from service-identity>=16.0.0->scrapy) (0.4.8)
# Requirement already satisfied: attrs>=19.1.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from service-identity>=16.0.0->scrapy) (20.3.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from cryptography>=2.0->scrapy) (1.14.3)
# Requirement already satisfied: Automat>=0.8.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from Twisted[http2]>=17.9.0->scrapy) (20.2.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from Twisted[http2]>=17.9.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=16.10.1 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from Twisted[http2]>=17.9.0->scrapy) (21.3.0)
# Requirement already satisfied: constantly>=15.1 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from Twisted[http2]>=17.9.0->scrapy) (15.1.0)
# Requirement already satisfied: priority<2.0,>=1.1.0; extra == "http2" in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from Twisted[http2]>=17.9.0->scrapy) (1.3.0)
# Requirement already satisfied: jmespath>=0.9.5 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from itemloaders>=1.0.1->scrapy) (0.10.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from h2<4.0,>=3.0->scrapy) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from h2<4.0,>=3.0->scrapy) (3.0.0)
# Requirement already satisfied: setuptools in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from zope.interface>=4.1.3->scrapy) (50.3.1.post20201107)
# Requirement already satisfied: pycparser in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.0->scrapy) (2.20)
# Requirement already satisfied: idna>=2.5 in /Users/usuario/opt/anaconda3/lib/python3.8/site-packages (from hyperlink>=17.1.1->Twisted[http2]>=17.9.0->scrapy) (2.10)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
from lxml import html
from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
import random
import re
import scrapy
import time

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
driver =webdriver.Chrome(PATH)

driver.get(url)

time.sleep(2)

[a.get_attribute('href')for a in driver.find_elements_by_class_name('h3.lh-condensed')][0:10]
# Out:
# []

# %%
driver.get(url)
time.sleep(2)
[a.text for a in driver.find_elements_by_class_name('h3.lh-condensed')]
# Out:
# []

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code

driver.get(url)

time.sleep(2)

[a.get_attribute('src') for a in driver.find_elements_by_tag_name('img')]
# Out:
# ['https://github.githubassets.com/images/search-key-slash.svg',
#  '',
#  '',
#  '',
#  '',
#  'https://avatars.githubusercontent.com/u/45662650?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/77636146?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/20466906?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/7396?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1242887?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/837573?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/36428?s=40&v=4',
#  'https://avatars.githubusercontent.com/in/2141?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/12038136?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/67130644?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/636814?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/24435787?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/17?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/24864343?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/33189705?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/10052309?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/2874908?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/14992195?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/2179708?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/836194?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/168301?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1302542?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/649202?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/38294?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/630936?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/8739626?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1336336?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/305268?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/7396?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1242887?s=40&v=4',
#  'https://avatars.githubusercontent.com/in/2141?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/837573?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/179599?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/7396?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1242887?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/837573?s=40&v=4',
#  'https://avatars.githubusercontent.com/in/2141?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/12653733?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/22989727?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/15628872?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/12605721?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/7845005?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/69842442?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/5554675?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/26175962?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/16448422?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/32151899?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/11529801?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/155158?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/4990625?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/14189615?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/10428420?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/9101033?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/327203?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/4108888?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1810515?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/302469?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/2836374?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1550771?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/18531147?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1695496?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/42288570?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1929?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/17700?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/836171?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/26403?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/209242?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/806360?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1326112?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/39515546?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/41147016?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/35119617?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1104190?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/4562643?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1924757?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/1088344?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/5674597?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/7830725?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/5931744?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/3739458?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/64708423?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/11612483?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/617552?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/13720491?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/19721752?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/23459515?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/2166111?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/15973859?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/585865?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/16308767?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/6033501?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/65916846?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/10135538?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/63583491?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/4039449?s=40&v=4',
#  'https://avatars.githubusercontent.com/in/2141?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/18406791?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/16239342?s=40&v=4',
#  'https://avatars.githubusercontent.com/in/29110?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/5781356?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/34477873?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/103110?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/633765?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/940557?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/9102141?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/40779233?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/22662425?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/18479688?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/17425982?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/15079146?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/22140675?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/19558793?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/9096508?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/49587577?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/569905?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/33297?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/26795429?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/318490?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/864569?s=40&v=4']

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code

driver.get(url)

time.sleep(2)

[a.get_attribute('href')for a in driver.find_elements_by_tag_name('a')]
# Out:
# ['https://github.com/trending/python?since=daily#start-of-content',
#  'https://github.com/',
#  'https://github.com/join?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2Ftrending%2Fpython&source=header',
#  'https://github.com/features',
#  'https://github.com/mobile',
#  'https://github.com/features/actions',
#  'https://github.com/features/codespaces',
#  'https://github.com/features/packages',
#  'https://github.com/features/security',
#  'https://github.com/features/code-review/',
#  'https://github.com/features/project-management/',
#  'https://github.com/features/integrations',
#  'https://github.com/sponsors',
#  'https://github.com/customer-stories',
#  'https://github.com/team',
#  'https://github.com/enterprise',
#  'https://github.com/explore',
#  'https://github.com/topics',
#  'https://github.com/collections',
#  'https://github.com/trending',
#  'https://lab.github.com/',
#  'https://opensource.guide/',
#  'https://github.com/readme',
#  'https://github.com/events',
#  'https://github.community/',
#  'https://education.github.com/',
#  'https://stars.github.com/',
#  'https://github.com/marketplace',
#  'https://github.com/pricing',
#  'https://github.com/pricing#feature-comparison',
#  'https://enterprise.github.com/contact',
#  'https://education.github.com/',
#  '',
#  '',
#  '',
#  '',
#  'https://github.com/login?return_to=%2Ftrending%2Fpython%3Fsince%3Ddaily',
#  'https://github.com/join?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2Ftrending%2Fpython&source=header',
#  'https://github.com/explore',
#  'https://github.com/topics',
#  'https://github.com/trending',
#  'https://github.com/collections',
#  'https://github.com/events',
#  'https://github.com/sponsors/community',
#  'https://github.com/explore/email',
#  'https://github.com/trending',
#  'https://github.com/trending/developers',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ab',
#  'https://github.com/trending/python?since=daily&spoken_language_code=aa',
#  'https://github.com/trending/python?since=daily&spoken_language_code=af',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ak',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sq',
#  'https://github.com/trending/python?since=daily&spoken_language_code=am',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ar',
#  'https://github.com/trending/python?since=daily&spoken_language_code=an',
#  'https://github.com/trending/python?since=daily&spoken_language_code=hy',
#  'https://github.com/trending/python?since=daily&spoken_language_code=as',
#  'https://github.com/trending/python?since=daily&spoken_language_code=av',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ae',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ay',
#  'https://github.com/trending/python?since=daily&spoken_language_code=az',
#  'https://github.com/trending/python?since=daily&spoken_language_code=bm',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ba',
#  'https://github.com/trending/python?since=daily&spoken_language_code=eu',
#  'https://github.com/trending/python?since=daily&spoken_language_code=be',
#  'https://github.com/trending/python?since=daily&spoken_language_code=bn',
#  'https://github.com/trending/python?since=daily&spoken_language_code=bh',
#  'https://github.com/trending/python?since=daily&spoken_language_code=bi',
#  'https://github.com/trending/python?since=daily&spoken_language_code=bs',
#  'https://github.com/trending/python?since=daily&spoken_language_code=br',
#  'https://github.com/trending/python?since=daily&spoken_language_code=bg',
#  'https://github.com/trending/python?since=daily&spoken_language_code=my',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ca',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ch',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ce',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ny',
#  'https://github.com/trending/python?since=daily&spoken_language_code=zh',
#  'https://github.com/trending/python?since=daily&spoken_language_code=cv',
#  'https://github.com/trending/python?since=daily&spoken_language_code=kw',
#  'https://github.com/trending/python?since=daily&spoken_language_code=co',
#  'https://github.com/trending/python?since=daily&spoken_language_code=cr',
#  'https://github.com/trending/python?since=daily&spoken_language_code=hr',
#  'https://github.com/trending/python?since=daily&spoken_language_code=cs',
#  'https://github.com/trending/python?since=daily&spoken_language_code=da',
#  'https://github.com/trending/python?since=daily&spoken_language_code=dv',
#  'https://github.com/trending/python?since=daily&spoken_language_code=nl',
#  'https://github.com/trending/python?since=daily&spoken_language_code=dz',
#  'https://github.com/trending/python?since=daily&spoken_language_code=en',
#  'https://github.com/trending/python?since=daily&spoken_language_code=eo',
#  'https://github.com/trending/python?since=daily&spoken_language_code=et',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ee',
#  'https://github.com/trending/python?since=daily&spoken_language_code=fo',
#  'https://github.com/trending/python?since=daily&spoken_language_code=fj',
#  'https://github.com/trending/python?since=daily&spoken_language_code=fi',
#  'https://github.com/trending/python?since=daily&spoken_language_code=fr',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ff',
#  'https://github.com/trending/python?since=daily&spoken_language_code=gl',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ka',
#  'https://github.com/trending/python?since=daily&spoken_language_code=de',
#  'https://github.com/trending/python?since=daily&spoken_language_code=el',
#  'https://github.com/trending/python?since=daily&spoken_language_code=gn',
#  'https://github.com/trending/python?since=daily&spoken_language_code=gu',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ht',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ha',
#  'https://github.com/trending/python?since=daily&spoken_language_code=he',
#  'https://github.com/trending/python?since=daily&spoken_language_code=hz',
#  'https://github.com/trending/python?since=daily&spoken_language_code=hi',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ho',
#  'https://github.com/trending/python?since=daily&spoken_language_code=hu',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ia',
#  'https://github.com/trending/python?since=daily&spoken_language_code=id',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ie',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ga',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ig',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ik',
#  'https://github.com/trending/python?since=daily&spoken_language_code=io',
#  'https://github.com/trending/python?since=daily&spoken_language_code=is',
#  'https://github.com/trending/python?since=daily&spoken_language_code=it',
#  'https://github.com/trending/python?since=daily&spoken_language_code=iu',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ja',
#  'https://github.com/trending/python?since=daily&spoken_language_code=jv',
#  'https://github.com/trending/python?since=daily&spoken_language_code=kl',
#  'https://github.com/trending/python?since=daily&spoken_language_code=kn',
#  'https://github.com/trending/python?since=daily&spoken_language_code=kr',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ks',
#  'https://github.com/trending/python?since=daily&spoken_language_code=kk',
#  'https://github.com/trending/python?since=daily&spoken_language_code=km',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ki',
#  'https://github.com/trending/python?since=daily&spoken_language_code=rw',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ky',
#  'https://github.com/trending/python?since=daily&spoken_language_code=kv',
#  'https://github.com/trending/python?since=daily&spoken_language_code=kg',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ko',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ku',
#  'https://github.com/trending/python?since=daily&spoken_language_code=kj',
#  'https://github.com/trending/python?since=daily&spoken_language_code=la',
#  'https://github.com/trending/python?since=daily&spoken_language_code=lb',
#  'https://github.com/trending/python?since=daily&spoken_language_code=lg',
#  'https://github.com/trending/python?since=daily&spoken_language_code=li',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ln',
#  'https://github.com/trending/python?since=daily&spoken_language_code=lo',
#  'https://github.com/trending/python?since=daily&spoken_language_code=lt',
#  'https://github.com/trending/python?since=daily&spoken_language_code=lu',
#  'https://github.com/trending/python?since=daily&spoken_language_code=lv',
#  'https://github.com/trending/python?since=daily&spoken_language_code=gv',
#  'https://github.com/trending/python?since=daily&spoken_language_code=mk',
#  'https://github.com/trending/python?since=daily&spoken_language_code=mg',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ms',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ml',
#  'https://github.com/trending/python?since=daily&spoken_language_code=mt',
#  'https://github.com/trending/python?since=daily&spoken_language_code=mi',
#  'https://github.com/trending/python?since=daily&spoken_language_code=mr',
#  'https://github.com/trending/python?since=daily&spoken_language_code=mh',
#  'https://github.com/trending/python?since=daily&spoken_language_code=mn',
#  'https://github.com/trending/python?since=daily&spoken_language_code=na',
#  'https://github.com/trending/python?since=daily&spoken_language_code=nv',
#  'https://github.com/trending/python?since=daily&spoken_language_code=nd',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ne',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ng',
#  'https://github.com/trending/python?since=daily&spoken_language_code=nb',
#  'https://github.com/trending/python?since=daily&spoken_language_code=nn',
#  'https://github.com/trending/python?since=daily&spoken_language_code=no',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ii',
#  'https://github.com/trending/python?since=daily&spoken_language_code=nr',
#  'https://github.com/trending/python?since=daily&spoken_language_code=oc',
#  'https://github.com/trending/python?since=daily&spoken_language_code=oj',
#  'https://github.com/trending/python?since=daily&spoken_language_code=cu',
#  'https://github.com/trending/python?since=daily&spoken_language_code=om',
#  'https://github.com/trending/python?since=daily&spoken_language_code=or',
#  'https://github.com/trending/python?since=daily&spoken_language_code=os',
#  'https://github.com/trending/python?since=daily&spoken_language_code=pa',
#  'https://github.com/trending/python?since=daily&spoken_language_code=pi',
#  'https://github.com/trending/python?since=daily&spoken_language_code=fa',
#  'https://github.com/trending/python?since=daily&spoken_language_code=pl',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ps',
#  'https://github.com/trending/python?since=daily&spoken_language_code=pt',
#  'https://github.com/trending/python?since=daily&spoken_language_code=qu',
#  'https://github.com/trending/python?since=daily&spoken_language_code=rm',
#  'https://github.com/trending/python?since=daily&spoken_language_code=rn',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ro',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ru',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sa',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sc',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sd',
#  'https://github.com/trending/python?since=daily&spoken_language_code=se',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sm',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sg',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sr',
#  'https://github.com/trending/python?since=daily&spoken_language_code=gd',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sn',
#  'https://github.com/trending/python?since=daily&spoken_language_code=si',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sk',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sl',
#  'https://github.com/trending/python?since=daily&spoken_language_code=so',
#  'https://github.com/trending/python?since=daily&spoken_language_code=st',
#  'https://github.com/trending/python?since=daily&spoken_language_code=es',
#  'https://github.com/trending/python?since=daily&spoken_language_code=su',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sw',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ss',
#  'https://github.com/trending/python?since=daily&spoken_language_code=sv',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ta',
#  'https://github.com/trending/python?since=daily&spoken_language_code=te',
#  'https://github.com/trending/python?since=daily&spoken_language_code=tg',
#  'https://github.com/trending/python?since=daily&spoken_language_code=th',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ti',
#  'https://github.com/trending/python?since=daily&spoken_language_code=bo',
#  'https://github.com/trending/python?since=daily&spoken_language_code=tk',
#  'https://github.com/trending/python?since=daily&spoken_language_code=tl',
#  'https://github.com/trending/python?since=daily&spoken_language_code=tn',
#  'https://github.com/trending/python?since=daily&spoken_language_code=to',
#  'https://github.com/trending/python?since=daily&spoken_language_code=tr',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ts',
#  'https://github.com/trending/python?since=daily&spoken_language_code=tt',
#  'https://github.com/trending/python?since=daily&spoken_language_code=tw',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ty',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ug',
#  'https://github.com/trending/python?since=daily&spoken_language_code=uk',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ur',
#  'https://github.com/trending/python?since=daily&spoken_language_code=uz',
#  'https://github.com/trending/python?since=daily&spoken_language_code=ve',
#  'https://github.com/trending/python?since=daily&spoken_language_code=vi',
#  'https://github.com/trending/python?since=daily&spoken_language_code=vo',
#  'https://github.com/trending/python?since=daily&spoken_language_code=wa',
#  'https://github.com/trending/python?since=daily&spoken_language_code=cy',
#  'https://github.com/trending/python?since=daily&spoken_language_code=wo',
#  'https://github.com/trending/python?since=daily&spoken_language_code=fy',
#  'https://github.com/trending/python?since=daily&spoken_language_code=xh',
#  'https://github.com/trending/python?since=daily&spoken_language_code=yi',
#  'https://github.com/trending/python?since=daily&spoken_language_code=yo',
#  'https://github.com/trending/python?since=daily&spoken_language_code=za',
#  'https://github.com/trending/python?since=daily&spoken_language_code=zu',
#  'https://github.com/trending?since=daily',
#  'https://github.com/trending/c++?since=daily',
#  'https://github.com/trending/html?since=daily',
#  'https://github.com/trending/java?since=daily',
#  'https://github.com/trending/javascript?since=daily',
#  'https://github.com/trending/php?since=daily',
#  'https://github.com/trending?since=daily',
#  'https://github.com/trending/ruby?since=daily',
#  'https://github.com/trending/unknown?since=daily',
#  'https://github.com/trending/1c-enterprise?since=daily',
#  'https://github.com/trending/4d?since=daily',
#  'https://github.com/trending/abap?since=daily',
#  'https://github.com/trending/abap-cds?since=daily',
#  'https://github.com/trending/abnf?since=daily',
#  'https://github.com/trending/actionscript?since=daily',
#  'https://github.com/trending/ada?since=daily',
#  'https://github.com/trending/adobe-font-metrics?since=daily',
#  'https://github.com/trending/agda?since=daily',
#  'https://github.com/trending/ags-script?since=daily',
#  'https://github.com/trending/al?since=daily',
#  'https://github.com/trending/al?since=daily',
#  'https://github.com/trending/alloy?since=daily',
#  'https://github.com/trending/alpine-abuild?since=daily',
#  'https://github.com/trending/altium-designer?since=daily',
#  'https://github.com/trending/ampl?since=daily',
#  'https://github.com/trending/angelscript?since=daily',
#  'https://github.com/trending/ant-build-system?since=daily',
#  'https://github.com/trending/antlr?since=daily',
#  'https://github.com/trending/apacheconf?since=daily',
#  'https://github.com/trending/apex?since=daily',
#  'https://github.com/trending/api-blueprint?since=daily',
#  'https://github.com/trending/apl?since=daily',
#  'https://github.com/trending/apollo-guidance-computer?since=daily',
#  'https://github.com/trending/applescript?since=daily',
#  'https://github.com/trending/arc?since=daily',
#  'https://github.com/trending/asciidoc?since=daily',
#  'https://github.com/trending/asl?since=daily',
#  'https://github.com/trending/asn.1?since=daily',
#  'https://github.com/trending/classic-asp?since=daily',
#  'https://github.com/trending/asp.net?since=daily',
#  'https://github.com/trending/aspectj?since=daily',
#  'https://github.com/trending/assembly?since=daily',
#  'https://github.com/trending/asymptote?since=daily',
#  'https://github.com/trending/ats?since=daily',
#  'https://github.com/trending/augeas?since=daily',
#  'https://github.com/trending/autohotkey?since=daily',
#  'https://github.com/trending/autoit?since=daily',
#  'https://github.com/trending/avro-idl?since=daily',
#  'https://github.com/trending/awk?since=daily',
#  'https://github.com/trending/ballerina?since=daily',
#  'https://github.com/trending/basic?since=daily',
#  'https://github.com/trending/batchfile?since=daily',
#  'https://github.com/trending/beef?since=daily',
#  'https://github.com/trending/befunge?since=daily',
#  'https://github.com/trending/bibtex?since=daily',
#  'https://github.com/trending/bicep?since=daily',
#  'https://github.com/trending/bison?since=daily',
#  'https://github.com/trending/bitbake?since=daily',
#  'https://github.com/trending/blade?since=daily',
#  'https://github.com/trending/blitzbasic?since=daily',
#  'https://github.com/trending/blitzmax?since=daily',
#  'https://github.com/trending/bluespec?since=daily',
#  'https://github.com/trending/boo?since=daily',
#  'https://github.com/trending/boogie?since=daily',
#  'https://github.com/trending/brainfuck?since=daily',
#  'https://github.com/trending/brightscript?since=daily',
#  'https://github.com/trending/zeek?since=daily',
#  'https://github.com/trending/browserslist?since=daily',
#  'https://github.com/trending/c?since=daily',
#  'https://github.com/trending/c%23?since=daily',
#  'https://github.com/trending/c-objdump?since=daily',
#  'https://github.com/trending/c2hs-haskell?since=daily',
#  'https://github.com/trending/cabal-config?since=daily',
#  "https://github.com/trending/cap'n-proto?since=daily",
#  'https://github.com/trending/cartocss?since=daily',
#  'https://github.com/trending/ceylon?since=daily',
#  'https://github.com/trending/chapel?since=daily',
#  'https://github.com/trending/charity?since=daily',
#  'https://github.com/trending/chuck?since=daily',
#  'https://github.com/trending/cirru?since=daily',
#  'https://github.com/trending/clarion?since=daily',
#  'https://github.com/trending/classic-asp?since=daily',
#  'https://github.com/trending/clean?since=daily',
#  'https://github.com/trending/click?since=daily',
#  'https://github.com/trending/clips?since=daily',
#  'https://github.com/trending/clojure?since=daily',
#  'https://github.com/trending/closure-templates?since=daily',
#  'https://github.com/trending/cloud-firestore-security-rules?since=daily',
#  'https://github.com/trending/cmake?since=daily',
#  'https://github.com/trending/cobol?since=daily',
#  'https://github.com/trending/codeql?since=daily',
#  'https://github.com/trending/coffeescript?since=daily',
#  'https://github.com/trending/coldfusion?since=daily',
#  'https://github.com/trending/coldfusion-cfc?since=daily',
#  'https://github.com/trending/collada?since=daily',
#  'https://github.com/trending/common-lisp?since=daily',
#  'https://github.com/trending/common-workflow-language?since=daily',
#  'https://github.com/trending/component-pascal?since=daily',
#  'https://github.com/trending/conll-u?since=daily',
#  'https://github.com/trending/cool?since=daily',
#  'https://github.com/trending/coq?since=daily',
#  'https://github.com/trending/cpp-objdump?since=daily',
#  'https://github.com/trending/creole?since=daily',
#  'https://github.com/trending/crystal?since=daily',
#  'https://github.com/trending/cson?since=daily',
#  'https://github.com/trending/csound?since=daily',
#  'https://github.com/trending/csound-document?since=daily',
#  'https://github.com/trending/csound-score?since=daily',
#  'https://github.com/trending/css?since=daily',
#  'https://github.com/trending/csv?since=daily',
#  'https://github.com/trending/cuda?since=daily',
#  'https://github.com/trending/curl-config?since=daily',
#  'https://github.com/trending/cweb?since=daily',
#  'https://github.com/trending/cycript?since=daily',
#  'https://github.com/trending/cython?since=daily',
#  'https://github.com/trending/d?since=daily',
#  'https://github.com/trending/d-objdump?since=daily',
#  'https://github.com/trending/dafny?since=daily',
#  'https://github.com/trending/darcs-patch?since=daily',
#  'https://github.com/trending/dart?since=daily',
#  'https://github.com/trending/dataweave?since=daily',
#  'https://github.com/trending/desktop?since=daily',
#  'https://github.com/trending/dhall?since=daily',
#  'https://github.com/trending/diff?since=daily',
#  'https://github.com/trending/digital-command-language?since=daily',
#  'https://github.com/trending/dircolors?since=daily',
#  'https://github.com/trending/directx-3d-file?since=daily',
#  'https://github.com/trending/dm?since=daily',
#  'https://github.com/trending/dns-zone?since=daily',
#  'https://github.com/trending/dockerfile?since=daily',
#  'https://github.com/trending/dogescript?since=daily',
#  'https://github.com/trending/dtrace?since=daily',
#  'https://github.com/trending/dylan?since=daily',
#  'https://github.com/trending/e?since=daily',
#  'https://github.com/trending/eagle?since=daily',
#  'https://github.com/trending/easybuild?since=daily',
#  'https://github.com/trending/ebnf?since=daily',
#  'https://github.com/trending/ec?since=daily',
#  'https://github.com/trending/ecere-projects?since=daily',
#  'https://github.com/trending/ecl?since=daily',
#  'https://github.com/trending/eclipse?since=daily',
#  'https://github.com/trending/editorconfig?since=daily',
#  'https://github.com/trending/edje-data-collection?since=daily',
#  'https://github.com/trending/edn?since=daily',
#  'https://github.com/trending/eiffel?since=daily',
#  'https://github.com/trending/ejs?since=daily',
#  'https://github.com/trending/elixir?since=daily',
#  'https://github.com/trending/elm?since=daily',
#  'https://github.com/trending/emacs-lisp?since=daily',
#  'https://github.com/trending/emberscript?since=daily',
#  'https://github.com/trending/eml?since=daily',
#  'https://github.com/trending/eq?since=daily',
#  'https://github.com/trending/erlang?since=daily',
#  'https://github.com/trending/f%23?since=daily',
#  'https://github.com/trending/f*?since=daily',
#  'https://github.com/trending/factor?since=daily',
#  'https://github.com/trending/fancy?since=daily',
#  'https://github.com/trending/fantom?since=daily',
#  'https://github.com/trending/faust?since=daily',
#  'https://github.com/trending/figlet-font?since=daily',
#  'https://github.com/trending/filebench-wml?since=daily',
#  'https://github.com/trending/filterscript?since=daily',
#  'https://github.com/trending/fish?since=daily',
#  'https://github.com/trending/flux?since=daily',
#  'https://github.com/trending/formatted?since=daily',
#  'https://github.com/trending/forth?since=daily',
#  'https://github.com/trending/fortran?since=daily',
#  'https://github.com/trending/fortran-free-form?since=daily',
#  'https://github.com/trending/freebasic?since=daily',
#  'https://github.com/trending/freemarker?since=daily',
#  'https://github.com/trending/frege?since=daily',
#  'https://github.com/trending/futhark?since=daily',
#  'https://github.com/trending/g-code?since=daily',
#  'https://github.com/trending/game-maker-language?since=daily',
#  'https://github.com/trending/gaml?since=daily',
#  'https://github.com/trending/gams?since=daily',
#  'https://github.com/trending/gap?since=daily',
#  'https://github.com/trending/gcc-machine-description?since=daily',
#  'https://github.com/trending/gdb?since=daily',
#  'https://github.com/trending/gdscript?since=daily',
#  'https://github.com/trending/gedcom?since=daily',
#  'https://github.com/trending/genie?since=daily',
#  'https://github.com/trending/genshi?since=daily',
#  'https://github.com/trending/gentoo-ebuild?since=daily',
#  'https://github.com/trending/gentoo-eclass?since=daily',
#  'https://github.com/trending/gerber-image?since=daily',
#  'https://github.com/trending/gettext-catalog?since=daily',
#  'https://github.com/trending/gherkin?since=daily',
#  'https://github.com/trending/git-attributes?since=daily',
#  'https://github.com/trending/git-config?since=daily',
#  'https://github.com/trending/glsl?since=daily',
#  'https://github.com/trending/glyph?since=daily',
#  'https://github.com/trending/glyph-bitmap-distribution-format?since=daily',
#  'https://github.com/trending/gn?since=daily',
#  'https://github.com/trending/gnuplot?since=daily',
#  'https://github.com/trending/go?since=daily',
#  'https://github.com/trending/golo?since=daily',
#  'https://github.com/trending/gosu?since=daily',
#  'https://github.com/trending/grace?since=daily',
#  'https://github.com/trending/gradle?since=daily',
#  'https://github.com/trending/grammatical-framework?since=daily',
#  'https://github.com/trending/graph-modeling-language?since=daily',
#  'https://github.com/trending/graphql?since=daily',
#  'https://github.com/trending/graphviz-(dot)?since=daily',
#  'https://github.com/trending/groovy?since=daily',
#  'https://github.com/trending/groovy-server-pages?since=daily',
#  'https://github.com/trending/hack?since=daily',
#  'https://github.com/trending/haml?since=daily',
#  'https://github.com/trending/handlebars?since=daily',
#  'https://github.com/trending/haproxy?since=daily',
#  'https://github.com/trending/harbour?since=daily',
#  'https://github.com/trending/haskell?since=daily',
#  'https://github.com/trending/haxe?since=daily',
#  'https://github.com/trending/hcl?since=daily',
#  'https://github.com/trending/hiveql?since=daily',
#  'https://github.com/trending/hlsl?since=daily',
#  'https://github.com/trending/holyc?since=daily',
#  'https://github.com/trending/jinja?since=daily',
#  'https://github.com/trending/html+ecr?since=daily',
#  'https://github.com/trending/html+eex?since=daily',
#  'https://github.com/trending/html+erb?since=daily',
#  'https://github.com/trending/html+php?since=daily',
#  'https://github.com/trending/html+razor?since=daily',
#  'https://github.com/trending/http?since=daily',
#  'https://github.com/trending/hxml?since=daily',
#  'https://github.com/trending/hy?since=daily',
#  'https://github.com/trending/hyphy?since=daily',
#  'https://github.com/trending/idl?since=daily',
#  'https://github.com/trending/idris?since=daily',
#  'https://github.com/trending/ignore-list?since=daily',
#  'https://github.com/trending/igor-pro?since=daily',
#  'https://github.com/trending/imagej-macro?since=daily',
#  'https://github.com/trending/inform-7?since=daily',
#  'https://github.com/trending/ini?since=daily',
#  'https://github.com/trending/inno-setup?since=daily',
#  'https://github.com/trending/io?since=daily',
#  'https://github.com/trending/ioke?since=daily',
#  'https://github.com/trending/irc-log?since=daily',
#  'https://github.com/trending/isabelle?since=daily',
#  'https://github.com/trending/isabelle-root?since=daily',
#  'https://github.com/trending/j?since=daily',
#  'https://github.com/trending/jasmin?since=daily',
#  'https://github.com/trending/java-properties?since=daily',
#  'https://github.com/trending/java-server-pages?since=daily',
#  'https://github.com/trending/javascript+erb?since=daily',
#  'https://github.com/trending/jflex?since=daily',
#  'https://github.com/trending/jinja?since=daily',
#  'https://github.com/trending/jison?since=daily',
#  'https://github.com/trending/jison-lex?since=daily',
#  'https://github.com/trending/jolie?since=daily',
#  'https://github.com/trending/jq?since=daily',
#  'https://github.com/trending/json?since=daily',
#  'https://github.com/trending/json-with-comments?since=daily',
#  'https://github.com/trending/json5?since=daily',
#  'https://github.com/trending/jsoniq?since=daily',
#  'https://github.com/trending/jsonld?since=daily',
#  'https://github.com/trending/jsonnet?since=daily',
#  'https://github.com/trending/julia?since=daily',
#  'https://github.com/trending/jupyter-notebook?since=daily',
#  'https://github.com/trending/kaitai-struct?since=daily',
#  'https://github.com/trending/kicad-layout?since=daily',
#  'https://github.com/trending/kicad-legacy-layout?since=daily',
#  'https://github.com/trending/kicad-schematic?since=daily',
#  'https://github.com/trending/kit?since=daily',
#  'https://github.com/trending/kotlin?since=daily',
#  'https://github.com/trending/krl?since=daily',
#  'https://github.com/trending/labview?since=daily',
#  'https://github.com/trending/lark?since=daily',
#  'https://github.com/trending/lasso?since=daily',
#  'https://github.com/trending/latte?since=daily',
#  'https://github.com/trending/lean?since=daily',
#  'https://github.com/trending/less?since=daily',
#  'https://github.com/trending/lex?since=daily',
#  'https://github.com/trending/lfe?since=daily',
#  'https://github.com/trending/lilypond?since=daily',
#  'https://github.com/trending/limbo?since=daily',
#  'https://github.com/trending/linker-script?since=daily',
#  'https://github.com/trending/linux-kernel-module?since=daily',
#  'https://github.com/trending/liquid?since=daily',
#  'https://github.com/trending/literate-agda?since=daily',
#  'https://github.com/trending/literate-coffeescript?since=daily',
#  'https://github.com/trending/literate-haskell?since=daily',
#  'https://github.com/trending/livescript?since=daily',
#  'https://github.com/trending/llvm?since=daily',
#  'https://github.com/trending/logos?since=daily',
#  'https://github.com/trending/logtalk?since=daily',
#  'https://github.com/trending/lolcode?since=daily',
#  'https://github.com/trending/lookml?since=daily',
#  'https://github.com/trending/loomscript?since=daily',
#  'https://github.com/trending/lsl?since=daily',
#  'https://github.com/trending/ltspice-symbol?since=daily',
#  'https://github.com/trending/lua?since=daily',
#  'https://github.com/trending/m?since=daily',
#  'https://github.com/trending/m4?since=daily',
#  'https://github.com/trending/m4sugar?since=daily',
#  'https://github.com/trending/macaulay2?since=daily',
#  'https://github.com/trending/makefile?since=daily',
#  'https://github.com/trending/mako?since=daily',
#  'https://github.com/trending/markdown?since=daily',
#  'https://github.com/trending/marko?since=daily',
#  'https://github.com/trending/mask?since=daily',
#  'https://github.com/trending/mathematica?since=daily',
#  'https://github.com/trending/matlab?since=daily',
#  'https://github.com/trending/maven-pom?since=daily',
#  'https://github.com/trending/max?since=daily',
#  'https://github.com/trending/maxscript?since=daily',
#  'https://github.com/trending/mcfunction?since=daily',
#  'https://github.com/trending/mediawiki?since=daily',
#  'https://github.com/trending/mercury?since=daily',
#  'https://github.com/trending/meson?since=daily',
#  'https://github.com/trending/metal?since=daily',
#  'https://github.com/trending/microsoft-developer-studio-project?since=daily',
#  'https://github.com/trending/microsoft-visual-studio-solution?since=daily',
#  'https://github.com/trending/minid?since=daily',
#  'https://github.com/trending/mirah?since=daily',
#  'https://github.com/trending/mirc-script?since=daily',
#  'https://github.com/trending/mlir?since=daily',
#  'https://github.com/trending/modelica?since=daily',
#  'https://github.com/trending/modula-2?since=daily',
#  'https://github.com/trending/modula-3?since=daily',
#  'https://github.com/trending/module-management-system?since=daily',
#  'https://github.com/trending/monkey?since=daily',
#  'https://github.com/trending/moocode?since=daily',
#  'https://github.com/trending/moonscript?since=daily',
#  'https://github.com/trending/motorola-68k-assembly?since=daily',
#  'https://github.com/trending/mql4?since=daily',
#  'https://github.com/trending/mql5?since=daily',
#  'https://github.com/trending/mtml?since=daily',
#  'https://github.com/trending/muf?since=daily',
#  'https://github.com/trending/mupad?since=daily',
#  'https://github.com/trending/muse?since=daily',
#  'https://github.com/trending/mustache?since=daily',
#  'https://github.com/trending/myghty?since=daily',
#  'https://github.com/trending/nanorc?since=daily',
#  'https://github.com/trending/nasl?since=daily',
#  'https://github.com/trending/ncl?since=daily',
#  'https://github.com/trending/nearley?since=daily',
#  'https://github.com/trending/nemerle?since=daily',
#  'https://github.com/trending/neon?since=daily',
#  'https://github.com/trending/nesc?since=daily',
#  'https://github.com/trending/netlinx?since=daily',
#  'https://github.com/trending/netlinx+erb?since=daily',
#  'https://github.com/trending/netlogo?since=daily',
#  'https://github.com/trending/newlisp?since=daily',
#  'https://github.com/trending/nextflow?since=daily',
#  'https://github.com/trending/nginx?since=daily',
#  'https://github.com/trending/nim?since=daily',
#  'https://github.com/trending/ninja?since=daily',
#  'https://github.com/trending/nit?since=daily',
#  'https://github.com/trending/nix?since=daily',
#  'https://github.com/trending/nl?since=daily',
#  'https://github.com/trending/npm-config?since=daily',
#  'https://github.com/trending/nsis?since=daily',
#  'https://github.com/trending/nu?since=daily',
#  'https://github.com/trending/numpy?since=daily',
#  'https://github.com/trending/nunjucks?since=daily',
#  'https://github.com/trending/nwscript?since=daily',
#  'https://github.com/trending/objdump?since=daily',
#  'https://github.com/trending/object-data-instance-notation?since=daily',
#  'https://github.com/trending/objective-c?since=daily',
#  'https://github.com/trending/objective-c++?since=daily',
#  'https://github.com/trending/objective-j?since=daily',
#  'https://github.com/trending/objectscript?since=daily',
#  'https://github.com/trending/ocaml?since=daily',
#  'https://github.com/trending/odin?since=daily',
#  'https://github.com/trending/omgrofl?since=daily',
#  'https://github.com/trending/ooc?since=daily',
#  'https://github.com/trending/opa?since=daily',
#  'https://github.com/trending/opal?since=daily',
#  'https://github.com/trending/open-policy-agent?since=daily',
#  'https://github.com/trending/opencl?since=daily',
#  'https://github.com/trending/openedge-abl?since=daily',
#  'https://github.com/trending/openqasm?since=daily',
#  'https://github.com/trending/openrc-runscript?since=daily',
#  'https://github.com/trending/openscad?since=daily',
#  'https://github.com/trending/openstep-property-list?since=daily',
#  'https://github.com/trending/opentype-feature-file?since=daily',
#  'https://github.com/trending/org?since=daily',
#  'https://github.com/trending/ox?since=daily',
#  'https://github.com/trending/oxygene?since=daily',
#  'https://github.com/trending/oz?since=daily',
#  'https://github.com/trending/p4?since=daily',
#  'https://github.com/trending/pan?since=daily',
#  'https://github.com/trending/papyrus?since=daily',
#  'https://github.com/trending/parrot?since=daily',
#  'https://github.com/trending/parrot-assembly?since=daily',
#  'https://github.com/trending/parrot-internal-representation?since=daily',
#  'https://github.com/trending/pascal?since=daily',
#  'https://github.com/trending/pawn?since=daily',
#  'https://github.com/trending/pep8?since=daily',
#  'https://github.com/trending/perl?since=daily',
#  'https://github.com/trending/pic?since=daily',
#  'https://github.com/trending/pickle?since=daily',
#  'https://github.com/trending/picolisp?since=daily',
#  'https://github.com/trending/piglatin?since=daily',
#  'https://github.com/trending/pike?since=daily',
#  'https://github.com/trending/plantuml?since=daily',
#  'https://github.com/trending/plpgsql?since=daily',
#  'https://github.com/trending/plsql?since=daily',
#  'https://github.com/trending/pod?since=daily',
#  'https://github.com/trending/pod-6?since=daily',
#  'https://github.com/trending/pogoscript?since=daily',
#  'https://github.com/trending/pony?since=daily',
#  'https://github.com/trending/postcss?since=daily',
#  'https://github.com/trending/postscript?since=daily',
#  'https://github.com/trending/pov-ray-sdl?since=daily',
#  'https://github.com/trending/powerbuilder?since=daily',
#  'https://github.com/trending/powershell?since=daily',
#  'https://github.com/trending/prisma?since=daily',
#  'https://github.com/trending/processing?since=daily',
#  'https://github.com/trending/proguard?since=daily',
#  'https://github.com/trending/prolog?since=daily',
#  'https://github.com/trending/propeller-spin?since=daily',
#  'https://github.com/trending/protocol-buffer?since=daily',
#  'https://github.com/trending/public-key?since=daily',
#  'https://github.com/trending/pug?since=daily',
#  'https://github.com/trending/puppet?since=daily',
#  'https://github.com/trending/pure-data?since=daily',
#  'https://github.com/trending/purebasic?since=daily',
#  'https://github.com/trending/purescript?since=daily',
#  'https://github.com/trending/python-console?since=daily',
#  'https://github.com/trending/python-traceback?since=daily',
#  'https://github.com/trending/q?since=daily',
#  'https://github.com/trending/q%23?since=daily',
#  'https://github.com/trending/qmake?since=daily',
#  'https://github.com/trending/qml?since=daily',
#  'https://github.com/trending/qt-script?since=daily',
#  'https://github.com/trending/quake?since=daily',
#  'https://github.com/trending/r?since=daily',
#  'https://github.com/trending/racket?since=daily',
#  'https://github.com/trending/ragel?since=daily',
#  'https://github.com/trending/raku?since=daily',
#  'https://github.com/trending/raml?since=daily',
#  'https://github.com/trending/rascal?since=daily',
#  'https://github.com/trending/raw-token-data?since=daily',
#  'https://github.com/trending/rdoc?since=daily',
#  'https://github.com/trending/readline-config?since=daily',
#  'https://github.com/trending/realbasic?since=daily',
#  'https://github.com/trending/reason?since=daily',
#  'https://github.com/trending/rebol?since=daily',
#  'https://github.com/trending/red?since=daily',
#  'https://github.com/trending/redcode?since=daily',
#  'https://github.com/trending/regular-expression?since=daily',
#  "https://github.com/trending/ren'py?since=daily",
#  'https://github.com/trending/renderscript?since=daily',
#  'https://github.com/trending/rescript?since=daily',
#  'https://github.com/trending/restructuredtext?since=daily',
#  'https://github.com/trending/rexx?since=daily',
#  'https://github.com/trending/rich-text-format?since=daily',
#  'https://github.com/trending/ring?since=daily',
#  'https://github.com/trending/riot?since=daily',
#  'https://github.com/trending/rmarkdown?since=daily',
#  'https://github.com/trending/robotframework?since=daily',
#  'https://github.com/trending/robots.txt?since=daily',
#  'https://github.com/trending/roff?since=daily',
#  'https://github.com/trending/roff-manpage?since=daily',
#  'https://github.com/trending/rouge?since=daily',
#  'https://github.com/trending/rpc?since=daily',
#  'https://github.com/trending/rpm-spec?since=daily',
#  'https://github.com/trending/runoff?since=daily',
#  'https://github.com/trending/rust?since=daily',
#  'https://github.com/trending/sage?since=daily',
#  'https://github.com/trending/saltstack?since=daily',
#  'https://github.com/trending/sas?since=daily',
#  'https://github.com/trending/sass?since=daily',
#  'https://github.com/trending/scala?since=daily',
#  'https://github.com/trending/scaml?since=daily',
#  'https://github.com/trending/scheme?since=daily',
#  'https://github.com/trending/scilab?since=daily',
#  'https://github.com/trending/scss?since=daily',
#  'https://github.com/trending/sed?since=daily',
#  'https://github.com/trending/self?since=daily',
#  'https://github.com/trending/shaderlab?since=daily',
#  'https://github.com/trending/shell?since=daily',
#  'https://github.com/trending/shellsession?since=daily',
#  'https://github.com/trending/shen?since=daily',
#  'https://github.com/trending/sieve?since=daily',
#  'https://github.com/trending/singularity?since=daily',
#  'https://github.com/trending/slash?since=daily',
#  'https://github.com/trending/slice?since=daily',
#  'https://github.com/trending/slim?since=daily',
#  'https://github.com/trending/smali?since=daily',
#  'https://github.com/trending/smalltalk?since=daily',
#  'https://github.com/trending/smarty?since=daily',
#  'https://github.com/trending/smpl?since=daily',
#  'https://github.com/trending/smt?since=daily',
#  'https://github.com/trending/solidity?since=daily',
#  'https://github.com/trending/sourcepawn?since=daily',
#  'https://github.com/trending/sparql?since=daily',
#  'https://github.com/trending/spline-font-database?since=daily',
#  'https://github.com/trending/sqf?since=daily',
#  'https://github.com/trending/sql?since=daily',
#  'https://github.com/trending/sqlpl?since=daily',
#  'https://github.com/trending/squirrel?since=daily',
#  'https://github.com/trending/srecode-template?since=daily',
#  'https://github.com/trending/ssh-config?since=daily',
#  'https://github.com/trending/stan?since=daily',
#  'https://github.com/trending/standard-ml?since=daily',
#  'https://github.com/trending/starlark?since=daily',
#  'https://github.com/trending/stata?since=daily',
#  'https://github.com/trending/ston?since=daily',
#  'https://github.com/trending/stringtemplate?since=daily',
#  'https://github.com/trending/stylus?since=daily',
#  'https://github.com/trending/subrip-text?since=daily',
#  'https://github.com/trending/sugarss?since=daily',
#  'https://github.com/trending/supercollider?since=daily',
#  'https://github.com/trending/svelte?since=daily',
#  'https://github.com/trending/svg?since=daily',
#  'https://github.com/trending/swift?since=daily',
#  'https://github.com/trending/swig?since=daily',
#  'https://github.com/trending/systemverilog?since=daily',
#  'https://github.com/trending/tcl?since=daily',
#  'https://github.com/trending/tcsh?since=daily',
#  'https://github.com/trending/tea?since=daily',
#  'https://github.com/trending/terra?since=daily',
#  'https://github.com/trending/tex?since=daily',
#  'https://github.com/trending/texinfo?since=daily',
#  'https://github.com/trending/text?since=daily',
#  'https://github.com/trending/textile?since=daily',
#  'https://github.com/trending/thrift?since=daily',
#  'https://github.com/trending/ti-program?since=daily',
#  'https://github.com/trending/tla?since=daily',
#  'https://github.com/trending/toml?since=daily',
#  'https://github.com/trending/tsql?since=daily',
#  'https://github.com/trending/tsv?since=daily',
#  'https://github.com/trending/tsx?since=daily',
#  'https://github.com/trending/turing?since=daily',
#  'https://github.com/trending/turtle?since=daily',
#  'https://github.com/trending/twig?since=daily',
#  'https://github.com/trending/txl?since=daily',
#  'https://github.com/trending/type-language?since=daily',
#  'https://github.com/trending/typescript?since=daily',
#  'https://github.com/trending/unified-parallel-c?since=daily',
#  'https://github.com/trending/unity3d-asset?since=daily',
#  'https://github.com/trending/unix-assembly?since=daily',
#  'https://github.com/trending/uno?since=daily',
#  'https://github.com/trending/unrealscript?since=daily',
#  'https://github.com/trending/urweb?since=daily',
#  'https://github.com/trending/v?since=daily',
#  'https://github.com/trending/vala?since=daily',
#  'https://github.com/trending/vba?since=daily',
#  'https://github.com/trending/vbscript?since=daily',
#  'https://github.com/trending/vcl?since=daily',
#  'https://github.com/trending/verilog?since=daily',
#  'https://github.com/trending/vhdl?since=daily',
#  'https://github.com/trending/vim-help-file?since=daily',
#  'https://github.com/trending/vim-script?since=daily',
#  'https://github.com/trending/vim-snippet?since=daily',
#  'https://github.com/trending/visual-basic-.net?since=daily',
#  'https://github.com/trending/visual-basic-.net?since=daily',
#  'https://github.com/trending/volt?since=daily',
#  'https://github.com/trending/vue?since=daily',
#  'https://github.com/trending/wavefront-material?since=daily',
#  'https://github.com/trending/wavefront-object?since=daily',
#  'https://github.com/trending/wdl?since=daily',
#  'https://github.com/trending/web-ontology-language?since=daily',
#  'https://github.com/trending/webassembly?since=daily',
#  'https://github.com/trending/webidl?since=daily',
#  'https://github.com/trending/webvtt?since=daily',
#  'https://github.com/trending/wget-config?since=daily',
#  'https://github.com/trending/windows-registry-entries?since=daily',
#  'https://github.com/trending/wisp?since=daily',
#  'https://github.com/trending/wollok?since=daily',
#  'https://github.com/trending/world-of-warcraft-addon-data?since=daily',
#  'https://github.com/trending/x-bitmap?since=daily',
#  'https://github.com/trending/x-font-directory-index?since=daily',
#  'https://github.com/trending/x-pixmap?since=daily',
#  'https://github.com/trending/x10?since=daily',
#  'https://github.com/trending/xbase?since=daily',
#  'https://github.com/trending/xc?since=daily',
#  'https://github.com/trending/xcompose?since=daily',
#  'https://github.com/trending/xml?since=daily',
#  'https://github.com/trending/xml-property-list?since=daily',
#  'https://github.com/trending/xojo?since=daily',
#  'https://github.com/trending/xonsh?since=daily',
#  'https://github.com/trending/xpages?since=daily',
#  'https://github.com/trending/xproc?since=daily',
#  'https://github.com/trending/xquery?since=daily',
#  'https://github.com/trending/xs?since=daily',
#  'https://github.com/trending/xslt?since=daily',
#  'https://github.com/trending/xtend?since=daily',
#  'https://github.com/trending/yacc?since=daily',
#  'https://github.com/trending/yaml?since=daily',
#  'https://github.com/trending/yang?since=daily',
#  'https://github.com/trending/yara?since=daily',
#  'https://github.com/trending/yasnippet?since=daily',
#  'https://github.com/trending/zap?since=daily',
#  'https://github.com/trending/zeek?since=daily',
#  'https://github.com/trending/zenscript?since=daily',
#  'https://github.com/trending/zephir?since=daily',
#  'https://github.com/trending/zig?since=daily',
#  'https://github.com/trending/zil?since=daily',
#  'https://github.com/trending/zimpl?since=daily',
#  'https://github.com/trending/python?since=daily',
#  'https://github.com/trending/python?since=weekly',
#  'https://github.com/trending/python?since=monthly',
#  'https://github.com/login?return_to=%2FCyberPunkMetalHead%2FBinance-volatility-trading-bot',
#  'https://github.com/CyberPunkMetalHead/Binance-volatility-trading-bot',
#  'https://github.com/CyberPunkMetalHead/Binance-volatility-trading-bot/stargazers',
#  'https://github.com/CyberPunkMetalHead/Binance-volatility-trading-bot/network/members.Binance-volatility-trading-bot',
#  'https://github.com/CyberPunkMetalHead',
#  'https://github.com/ShogunMan',
#  'https://github.com/getsec',
#  'https://github.com/Davidobot',
#  'https://github.com/Rudlu',
#  'https://github.com/login?return_to=%2Fpallets%2Fflask',
#  'https://github.com/pallets/flask',
#  'https://github.com/pallets/flask/stargazers',
#  'https://github.com/pallets/flask/network/members.flask',
#  'https://github.com/mitsuhiko',
#  'https://github.com/davidism',
#  'https://github.com/untitaker',
#  'https://github.com/rduplain',
#  'https://github.com/apps/dependabot-preview',
#  'https://github.com/login?return_to=%2FCorentinJ%2FReal-Time-Voice-Cloning',
#  'https://github.com/CorentinJ/Real-Time-Voice-Cloning',
#  'https://github.com/CorentinJ/Real-Time-Voice-Cloning/stargazers',
#  'https://github.com/CorentinJ/Real-Time-Voice-Cloning/network/members.Real-Time-Voice-Cloning',
#  'https://github.com/CorentinJ',
#  'https://github.com/blue-fish',
#  'https://github.com/alexpeattie',
#  'https://github.com/matheusfillipe',
#  'https://github.com/vanpelt',
#  'https://github.com/login?return_to=%2Faliparlakci%2Fbulk-downloader-for-reddit',
#  'https://github.com/aliparlakci/bulk-downloader-for-reddit',
#  'https://github.com/aliparlakci/bulk-downloader-for-reddit/stargazers',
#  'https://github.com/aliparlakci/bulk-downloader-for-reddit/network/members.bulk-downloader-for-reddit',
#  'https://github.com/aliparlakci',
#  'https://github.com/Serene-Arc',
#  'https://github.com/vladdoster',
#  'https://github.com/EkriirkE',
#  'https://github.com/DanClowry',
#  'https://github.com/sponsors/minimaxir',
#  'https://github.com/login?return_to=%2Fminimaxir%2Fbig-list-of-naughty-strings',
#  'https://github.com/minimaxir/big-list-of-naughty-strings',
#  'https://github.com/minimaxir/big-list-of-naughty-strings/stargazers',
#  'https://github.com/minimaxir/big-list-of-naughty-strings/network/members.big-list-of-naughty-strings',
#  'https://github.com/minimaxir',
#  'https://github.com/jlennox',
#  'https://github.com/l0b0',
#  'https://github.com/06b',
#  'https://github.com/TheJambo',
#  'https://github.com/login?return_to=%2Fpyodide%2Fpyodide',
#  'https://github.com/pyodide/pyodide',
#  'https://github.com/pyodide/pyodide/stargazers',
#  'https://github.com/pyodide/pyodide/network/members.pyodide',
#  'https://github.com/mdboom',
#  'https://github.com/rth',
#  'https://github.com/hoodmane',
#  'https://github.com/dalcde',
#  'https://github.com/msabramo',
#  'https://github.com/login?return_to=%2Fpallets%2Fjinja',
#  'https://github.com/pallets/jinja',
#  'https://github.com/pallets/jinja/stargazers',
#  'https://github.com/pallets/jinja/network/members.jinja',
#  'https://github.com/mitsuhiko',
#  'https://github.com/davidism',
#  'https://github.com/apps/dependabot-preview',
#  'https://github.com/untitaker',
#  'https://github.com/ThiefMaster',
#  'https://github.com/login?return_to=%2Fpallets%2Fclick',
#  'https://github.com/pallets/click',
#  'https://github.com/pallets/click/stargazers',
#  'https://github.com/pallets/click/network/members.click',
#  'https://github.com/mitsuhiko',
#  'https://github.com/davidism',
#  'https://github.com/untitaker',
#  'https://github.com/apps/dependabot-preview',
#  'https://github.com/stopthatcow',
#  'https://github.com/login?return_to=%2FPaddlePaddle%2FPaddleDetection',
#  'https://github.com/PaddlePaddle/PaddleDetection',
#  'https://github.com/PaddlePaddle/PaddleDetection/stargazers',
#  'https://github.com/PaddlePaddle/PaddleDetection/network/members.PaddleDetection',
#  'https://github.com/jerrywgz',
#  'https://github.com/yghstill',
#  'https://github.com/heavengate',
#  'https://github.com/qingqing01',
#  'https://github.com/wangxinxin08',
#  'https://github.com/login?return_to=%2Flux-org%2Flux',
#  'https://github.com/lux-org/lux',
#  'https://github.com/lux-org/lux/stargazers',
#  'https://github.com/lux-org/lux/network/members.lux',
#  'https://github.com/dorisjlee',
#  'https://github.com/jaywoo123',
#  'https://github.com/19thyneb',
#  'https://github.com/westernguy2',
#  'https://github.com/caitlynachen',
#  'https://github.com/login?return_to=%2FNVIDIA%2FMegatron-LM',
#  'https://github.com/NVIDIA/Megatron-LM',
#  'https://github.com/NVIDIA/Megatron-LM/stargazers',
#  'https://github.com/NVIDIA/Megatron-LM/network/members.Megatron-LM',
#  'https://github.com/jaredcasper',
#  'https://github.com/mpatwary',
#  'https://github.com/borisfom',
#  'https://github.com/ekmb',
#  'https://github.com/raulpuric',
#  'https://github.com/sponsors/matplotlib',
#  'https://github.com/login?return_to=%2Fmatplotlib%2Fcheatsheets',
#  'https://github.com/matplotlib/cheatsheets',
#  'https://github.com/matplotlib/cheatsheets/stargazers',
#  'https://github.com/matplotlib/cheatsheets/network/members.cheatsheets',
#  'https://github.com/rougier',
#  'https://github.com/jimustafa',
#  'https://github.com/drammock',
#  'https://github.com/QuLogic',
#  'https://github.com/timhoffm',
#  'https://github.com/login?return_to=%2Fholoviz%2Fpanel',
#  'https://github.com/holoviz/panel',
#  'https://github.com/holoviz/panel/stargazers',
#  'https://github.com/holoviz/panel/network/members.panel',
#  'https://github.com/philippjfr',
#  'https://github.com/xavArtley',
#  'https://github.com/jbednar',
#  'https://github.com/MarcSkovMadsen',
#  'https://github.com/ceball',
#  'https://github.com/login?return_to=%2Fansible%2Fansible',
#  'https://github.com/ansible/ansible',
#  'https://docs.ansible.com/',
#  'https://github.com/ansible/ansible/stargazers',
#  'https://github.com/ansible/ansible/network/members.ansible',
#  'https://github.com/mpdehaan',
#  'https://github.com/bcoca',
#  'https://github.com/jimi-c',
#  'https://github.com/abadger',
#  'https://github.com/mattclay',
#  'https://github.com/sponsors/tiangolo',
#  'https://github.com/login?return_to=%2Ftiangolo%2Ffastapi',
#  'https://github.com/tiangolo/fastapi',
#  'https://github.com/tiangolo/fastapi/stargazers',
#  'https://github.com/tiangolo/fastapi/network/members.fastapi',
#  'https://github.com/tiangolo',
#  'https://github.com/waynerv',
#  'https://github.com/tokusumi',
#  'https://github.com/dmontagu',
#  'https://github.com/euri10',
#  'https://github.com/login?return_to=%2Fyearn%2Fwoofy',
#  'https://github.com/yearn/woofy',
#  'https://github.com/yearn/woofy/stargazers',
#  'https://github.com/yearn/woofy/network/members.woofy',
#  'https://github.com/banteg',
#  'https://github.com/login?return_to=%2Fjunyanz%2Fpytorch-CycleGAN-and-pix2pix',
#  'https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix',
#  'https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/stargazers',
#  'https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/network/members.pytorch-CycleGAN-and-pix2pix',
#  'https://github.com/junyanz',
#  'https://github.com/taesungp',
#  'https://github.com/SsnL',
#  'https://github.com/Naruto-Sasuke',
#  'https://github.com/CharlesDove',
#  'https://github.com/login?return_to=%2Fmartomi%2Fchiadog',
#  'https://github.com/martomi/chiadog',
#  'https://github.com/martomi/chiadog/stargazers',
#  'https://github.com/martomi/chiadog/network/members.chiadog',
#  'https://github.com/martomi',
#  'https://github.com/mikehw',
#  'https://github.com/greimela',
#  'https://github.com/ajacobson',
#  'https://github.com/Starttoaster',
#  'https://github.com/login?return_to=%2Fdbolya%2Fyolact',
#  'https://github.com/dbolya/yolact',
#  'https://github.com/dbolya/yolact/stargazers',
#  'https://github.com/dbolya/yolact/network/members.yolact',
#  'https://github.com/dbolya',
#  'https://github.com/Agade09',
#  'https://github.com/breznak',
#  'https://github.com/chongzhou96',
#  'https://github.com/dte',
#  'https://github.com/login?return_to=%2Fbridgecrewio%2Fcheckov',
#  'https://github.com/bridgecrewio/checkov',
#  ...]

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url3 = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
driver = webdriver.Chrome(PATH)

driver.get(url3)

time.sleep(2)

[a.text for a in driver.find_elements_by_class_name('usctitle')]
# Out:
# ['All titles in the format selected compressed into a zip archive.',
#  ' ',
#  'Title 1 - General Provisions ٭',
#  'Title 2 - The Congress',
#  'Title 3 - The President ٭',
#  'Title 4 - Flag and Seal, Seat of Government, and the States ٭',
#  'Title 5 - Government Organization and Employees ٭',
#  'Title 6 - Domestic Security',
#  'Title 7 - Agriculture',
#  'Title 8 - Aliens and Nationality',
#  'Title 9 - Arbitration ٭',
#  'Title 11 - Bankruptcy ٭',
#  'Title 12 - Banks and Banking',
#  'Title 13 - Census ٭',
#  'Title 14 - Coast Guard ٭',
#  'Title 15 - Commerce and Trade',
#  'Title 16 - Conservation',
#  'Title 17 - Copyrights ٭',
#  'Title 18 - Crimes and Criminal Procedure ٭',
#  'Title 19 - Customs Duties',
#  'Title 20 - Education',
#  'Title 21 - Food and Drugs',
#  'Title 22 - Foreign Relations and Intercourse',
#  'Title 23 - Highways ٭',
#  'Title 24 - Hospitals and Asylums',
#  'Title 25 - Indians',
#  'Title 26 - Internal Revenue Code',
#  'Title 27 - Intoxicating Liquors',
#  'Title 28 - Judiciary and Judicial Procedure ٭',
#  'Title 29 - Labor',
#  'Title 30 - Mineral Lands and Mining',
#  'Title 31 - Money and Finance ٭',
#  'Title 32 - National Guard ٭',
#  'Title 33 - Navigation and Navigable Waters',
#  'Title 34 - Crime Control and Law Enforcement',
#  'Title 35 - Patents ٭',
#  'Title 36 - Patriotic and National Observances, Ceremonies, and Organizations ٭',
#  'Title 37 - Pay and Allowances of the Uniformed Services ٭',
#  "Title 38 - Veterans' Benefits ٭",
#  'Title 39 - Postal Service ٭',
#  'Title 40 - Public Buildings, Property, and Works ٭',
#  'Title 41 - Public Contracts ٭',
#  'Title 42 - The Public Health and Welfare',
#  'Title 43 - Public Lands',
#  'Title 44 - Public Printing and Documents ٭',
#  'Title 45 - Railroads',
#  'Title 46 - Shipping ٭',
#  'Title 47 - Telecommunications',
#  'Title 48 - Territories and Insular Possessions',
#  'Title 49 - Transportation ٭',
#  'Title 50 - War and National Defense',
#  'Title 51 - National and Commercial Space Programs ٭',
#  'Title 52 - Voting and Elections',
#  'Title 53 [Reserved]',
#  'Title 54 - National Park Service and Related Programs ٭']

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
driver = webdriver.Chrome(PATH)
driver.get(url)

time.sleep(2)

[a.text for a in driver.find_elements_by_class_name('title')]
# Out:
# []

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code

driver = webdriver.Chrome(PATH)

driver.get(url)

time.sleep(2)

[a.text for a in driver.find_elements_by_class_name('tabev6')][0:10]
# Out:
# ['2021-05-13   23:10:35.8\n12min ago',
#  '2021-05-13   23:09:29.5\n13min ago',
#  '2021-05-13   23:03:52.4\n19min ago',
#  '2021-05-13   22:45:45.2\n37min ago',
#  '2021-05-13   22:40:00.7\n42min ago',
#  '2021-05-13   22:24:28.0\n58min ago',
#  '2021-05-13   22:13:12.0\n1hr 09min ago',
#  '2021-05-13   22:09:51.4\n1hr 13min ago',
#  '2021-05-13   21:38:46.5\n1hr 44min ago',
#  '2021-05-13   21:35:03.5\n1hr 47min ago']

# %%
driver.get(url)

time.sleep(2)

[a.text for a in driver.find_elements_by_class_name('tabev1')][0:10]
# Out:
# ['19.40 ',
#  '155.28 ',
#  '19.17 ',
#  '155.48 ',
#  '37.88 ',
#  '14.46 ',
#  '30.72 ',
#  '117.17 ',
#  '46.26 ',
#  '7.39 ']

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#your code

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code
driver=webdriver.Chrome(PATH)
url = 'https://twitter.com/SergioRamos'
driver.get(url)

time.sleep(5)

driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[1]/div[1]/div/div/div/div/div[2]/div')
find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[1]/div[1]/div/div/div/div/div[2]/div/div')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-795640673f41> in <module>
#       7
#       8 driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[1]/div[1]/div/div/div/div/div[2]/div')
# ----> 9 find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[1]/div[1]/div/div/div/div/div[2]/div/div')
#
# NameError: name 'find_element_by_xpath' is not defined

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code
driver=webdriver.Chrome(PATH)

driver.get(url)

time.sleep(2) 

cabeceras=driver.find_element_by_tag_name('thead')
cabeceras=[c.text.split("\n")[0] for c in cabeceras.find_elements_by_tag_name('th')]
line=[a.text for a in driver.find_elements_by_class_name('tbody')]
tabla=driver.find_element_by_xpath('//*[@id="mw-content-text"]/div[1]/table[2]')
filas=tabla.find_elements_by_tag_name('tr')
datos=[[e.text for e in f.find_elements_by_tag_name('td')] for f in filas]
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-62-94ed72ffbcf4> in <module>
#       6 time.sleep(2)
#       7
# ----> 8 cabeceras=driver.find_element_by_tag_name('thead')
#       9 cabeceras=[c.text.split("\n")[0] for c in cabeceras.find_elements_by_tag_name('th')]
#      10 line=[a.text for a in driver.find_elements_by_class_name('tbody')]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_tag_name(self, name)
#     528             element = driver.find_element_by_tag_name('h1')
#     529         """
# --> 530         return self.find_element(by=By.TAG_NAME, value=name)
#     531
#     532     def find_elements_by_tag_name(self, name):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"thead"}
#   (Session info: chrome=90.0.4430.212)

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
